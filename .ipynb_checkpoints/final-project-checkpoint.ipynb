# %%
import re
import requests
import requests_cache
import pandas as pd
from bs4 import BeautifulSoup
requests_cache.install_cache('bball_ref_cache')
import time
import numpy as np
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.preprocessing import scale
import matplotlib.pyplot as plt
import seaborn as sns


def bball_scraper(stat_type, start_year, end_year):
    bball_df = pd.DataFrame()
    url = 'http://www.basketball-reference.com/leagues/NBA_'
    for i in range(end_year-start_year + 1):
            url2 = url + r'%s_' %start_year + r'%s.html' %stat_type
            year = BeautifulSoup(requests.get(url2).content, "lxml")
            columns = year.find('thead').text.split('\n')
            stats = year.find('tbody')
            for figure in stats.find_all('tr', 'thead'):
                figure.decompose()
            data = stats.find_all('tr')
            player = [[td.getText() for td in data[i].findAll('td')] for i in range(len(data))]
            temp = pd.DataFrame(player)
            for index, row in temp.iterrows():
                if row[3] == 'TOT':
                    pname = row[0] 
                    temp = temp[(temp[0] != pname) | (temp[3] == 'TOT')]
            temp['Year'] = start_year
            bball_df = bball_df.append(temp)
            start_year = start_year + 1 
    columns = columns[3:-2]
    columns.append('Year')
    bball_df.columns = columns
    return bball_df

bball_per_game = bball_scraper('per_game', 2001, 2017)
bball_advanced = bball_scraper('advanced', 2001, 2017)
bball_100poss = bball_scraper('per_poss', 2001, 2017)
bball_per_game['MPG'] = bball_per_game['MP']
bball_per_game['MP'] = bball_advanced['MP']

# %%
from sklearn.metrics import silhouette_samples, silhouette_score
import matplotlib.cm as cm

def kmeans(data): 
    X = PCA(n_components=2).fit_transform(data)
    range_n_clusters = range(2,21)
    for n_clusters in range_n_clusters:
        fig, (ax1, ax2) = plt.subplots(1, 2)
        fig.set_size_inches(18, 7)

        # The 1st subplot is the silhouette plot
        # The silhouette coefficient can range from -1, 1 but in this example all
        # lie within [-0.1, 1]
        ax1.set_xlim([-0.1, 1])
        # The (n_clusters+1)*10 is for inserting blank space between silhouette
        # plots of individual clusters, to demarcate them clearly.
        ax1.set_ylim([0, len(X) + (n_clusters + 1) * 10])
        clusterer = KMeans(n_clusters=n_clusters, random_state=10)
        cluster_labels = clusterer.fit_predict(X)

        silhouette_avg = silhouette_score(X, cluster_labels)
        print("For n_clusters =", n_clusters,
              "The average silhouette_score is :", silhouette_avg)

        # Compute the silhouette scores for each sample
        sample_silhouette_values = silhouette_samples(X, cluster_labels)

        y_lower = 10
        for i in range(n_clusters):
            # Aggregate the silhouette scores for samples belonging to
            # cluster i, and sort them
            ith_cluster_silhouette_values = \
                sample_silhouette_values[cluster_labels == i]

            ith_cluster_silhouette_values.sort()

            size_cluster_i = ith_cluster_silhouette_values.shape[0]
            y_upper = y_lower + size_cluster_i

            color = cm.spectral(float(i) / n_clusters)
            ax1.fill_betweenx(np.arange(y_lower, y_upper),
                              0, ith_cluster_silhouette_values,
                              facecolor=color, edgecolor=color, alpha=0.7)

            # Label the silhouette plots with their cluster numbers at the middle
            ax1.text(-0.05, y_lower + 0.5 * size_cluster_i, str(i))

            # Compute the new y_lower for next plot
            y_lower = y_upper + 10  # 10 for the 0 samples

        ax1.set_title("The silhouette plot for the various clusters.")
        ax1.set_xlabel("The silhouette coefficient values")
        ax1.set_ylabel("Cluster label")

        # The vertical line for average silhouette score of all the values
        ax1.axvline(x=silhouette_avg, color="red", linestyle="--")

        ax1.set_yticks([])  # Clear the yaxis labels / ticks
        ax1.set_xticks([-0.1, 0, 0.2, 0.4, 0.6, 0.8, 1])

        # 2nd Plot showing the actual clusters formed
        colors = cm.spectral(cluster_labels.astype(float) / n_clusters)
        ax2.scatter(X[:, 0], X[:, 1], marker='.', s=30, lw=0, alpha=0.7,
                    c=colors)

        # Labeling the clusters
        centers = clusterer.cluster_centers_
        # Draw white circles at cluster centers
        ax2.scatter(centers[:, 0], centers[:, 1],
                    marker='o', c="white", alpha=1, s=200)

        for i, c in enumerate(centers):
            ax2.scatter(c[0], c[1], marker='$%d$' % i, alpha=1, s=50)

        ax2.set_title("The visualization of the clustered data.")
       
        plt.suptitle(("Silhouette analysis for KMeans clustering on sample data "
                      "with n_clusters = %d" % n_clusters),
                     fontsize=14, fontweight='bold')

        plt.show()

# %%
bball_per_game2 = bball_per_game.merge(bball_advanced)
bball_per_game2 = bball_per_game2.apply(lambda x: pd.to_numeric(x, errors='ignore'))
bball_per_game2 = bball_per_game2.loc[bball_per_game2['MP'] > 250]
bball_per_game2.fillna(0, inplace=True)
bball_per_game2 = bball_per_game2.set_index(bball_per_game2['Player'])
bball_per_game2 = bball_per_game2.drop(['Player','Pos','Age','Tm','G','GS','MP', 'PER',
                                        'PF','FGA','FG','FG%', '3P','2P','FT', 'TRB',
                                        'eFG%', 'VORP', 'BPM', 'DBPM', 'OBPM', 'USG%',
                                        'OWS', 'DWS', 'WS', 'WS/48','TRB%','FTr',
                                        'TS%', '3PAr'], axis = 1)
bball_per_game2 = bball_per_game2.drop(bball_per_game2[[-1,-2]], axis = 1)
bball_per_game2.head()
#kmeans(bball_per_game2)
# Out:
#                      3PA    3P%   2PA    2P%  FTA    FT%  ORB  DRB  AST  STL  \
# Player
# Mahmoud Abdul-Rauf   0.3  0.286   5.7  0.500  0.7  0.759  0.1  0.5  1.9  0.2
# Tariq Abdul-Wahad    0.3  0.400   3.5  0.386  1.2  0.583  0.5  1.6  0.8  0.5
# Shareef Abdur-Rahim  0.8  0.188  15.0  0.487  6.6  0.834  2.2  6.9  3.1  1.1
# Courtney Alexander   0.7  0.370   8.1  0.421  2.3  0.820  0.6  1.6  1.0  0.7
# Ray Allen            5.7  0.433  10.3  0.506  4.8  0.888  1.2  4.0  4.6  1.5
#
#                      ...   TOV  PS/G  Year   MPG  ORB%  DRB%  AST%  STL%  \
# Player               ...
# Mahmoud Abdul-Rauf   ...   0.6   6.5  2001  11.9   1.2   4.7  32.7   1.0
# Tariq Abdul-Wahad    ...   1.2   3.8  2001  14.5   3.6  11.8   8.1   1.7
# Shareef Abdur-Rahim  ...   2.9  20.5  2001  40.0   6.2  19.6  14.3   1.5
# Courtney Alexander   ...   1.2   9.5  2001  21.3   3.5   8.4   8.0   1.7
# Ray Allen            ...   2.5  22.0  2001  38.2   3.7  11.8  20.4   2.1
#
#                      BLK%  TOV%
# Player
# Mahmoud Abdul-Rauf    0.1   9.1
# Tariq Abdul-Wahad     2.1  21.1
# Shareef Abdur-Rahim   1.6  13.2
# Courtney Alexander    0.3  10.5
# Ray Allen             0.5  12.1
#
# [5 rows x 21 columns]

# %%
df = bball_per_game2.loc[bball_per_game2['Year'] == 2016]
from scipy.spatial.distance import pdist, squareform

dist = pdist(df, 'euclidean')
df_dist = pd.DataFrame(squareform(dist))
DistMatrix = df_dist.as_matrix()
test = DistMatrix[6] < 10
test = df.iloc[list(test)]
test
# Out:
#                          3PA    3P%  2PA    2P%  FTA    FT%  ORB  DRB  AST  \
# Player
# Quincy Acy               0.8  0.388  2.8  0.606  1.2  0.735  1.1  2.1  0.5
# Steven Adams             0.0  0.000  5.3  0.613  2.5  0.582  2.7  3.9  0.8
#
#                          STL%  BLK%  TOV%
# Player
# Quincy Acy                1.6   2.2  10.0
# Steven Adams              1.0   3.3  14.1
# Lavoy Allen               0.8   2.1  14.6
# Tony Allen                3.5   1.0  12.8
# Chris Andersen            1.9   2.9   9.3
# Darrell Arthur            1.8   2.6  11.4
# Brandon Bass              1.2   3.2   9.9
# Aron Baynes               0.9   3.2  12.8
# Nemanja Bjelica           1.2   1.6  15.3
# Trevor Booker             1.9   2.1  15.7
# Clint Capela              2.0   5.2  10.9
# Willie Cauley-Stein       1.6   3.8  10.5
# Ed Davis                  1.7   3.3  13.0
# Bryce Dejean-Jones        1.8   0.6  12.3
# Festus Ezeli              1.1   4.8  11.7
# Alonzo Gee                1.9   0.7  16.2
# Taj Gibson                1.2   2.9  12.1
# Aaron Gordon              1.6   2.4   9.0
# JaMychal Green            1.6   2.1  13.0
# Maurice Harkless          1.7   1.9  11.9
# John Henson               1.0   9.7  15.7
# Roy Hibbert               0.9   4.6  13.8
# Jordan Hill               1.2   2.0  13.2
# Solomon Hill              2.1   1.0  12.7
# Rondae Hollis-Jefferson   3.2   2.1  13.9
# Kris Humphries            0.9   2.2  10.3
# Jonas Jerebko             0.8   1.6  14.0
# Amir Johnson              1.4   3.6  16.4
# Terrence Jones            1.1   3.1  10.5
# Frank Kaminsky            1.1   2.0   8.9
# Kosta Koufos              1.3   3.8   8.9
# Joffrey Lauvergne         0.6   1.2  11.6
# Trey Lyles                1.0   1.1  12.1
# Ian Mahinmi               1.8   3.3  15.5
# Jarell Martin             1.1   1.7  11.7
# Chris McCullough          3.9   2.7  11.2
# Donatas Motiejunas        1.5   0.8  16.2
# Timofey Mozgov            0.9   3.5  15.0
# Larry Nance Jr.           2.1   1.4  11.3
# Johnny O'Bryant           1.1   0.8  12.0
# Miles Plumlee             1.2   4.9  13.4
# Bobby Portis              1.1   1.5  10.4
# Dwight Powell             1.8   2.0  10.0
# Robert Sacre              0.6   2.5  11.6
# JaKarr Sampson            1.0   2.2  15.9
# Luis Scola                1.5   1.4   9.7
# Thabo Sefolosha           2.4   1.7  14.1
# Henry Sims                1.7   4.3  11.7
# Tiago Splitter            1.7   1.6  12.0
# Amar'e Stoudemire         1.2   4.1  15.8
# Noah Vonleh               1.2   1.7  14.3
# Jeff Withey               1.7   6.8  13.0
# Cody Zeller               1.6   2.9  11.2
# Tyler Zeller              0.7   2.4  12.0
#
# [54 rows x 21 columns]

# %%
import networkx as nx
G = nx.from_numpy_matrix(DistMatrix)
A = nx.adjacency_matrix(G)
# Out:
# [[  0.          13.0477585   23.33709129 ...,  25.48566646  12.21056076
#     5.67043596]
#  [ 13.0477585    0.          18.53464928 ...,  16.86879465   6.76794356
#    14.69840325]
#  [ 23.33709129  18.53464928   0.         ...,  16.15096075  16.68507776
#    25.91981092]
#  ...,
#  [ 25.48566646  16.86879465  16.15096075 ...,   0.          14.11949167
#    25.81134903]
#  [ 12.21056076   6.76794356  16.68507776 ...,  14.11949167   0.
#    13.42116575]
#  [  5.67043596  14.69840325  25.91981092 ...,  25.81134903  13.42116575
#     0.        ]]

# %%
nx.draw_networkx(G)
plt.show()

# %%
bball_100poss2 = bball_100poss.drop(bball_100poss[[-4]], axis = 1)
bball_100poss2 = bball_100poss2.apply(lambda x: pd.to_numeric(x, errors='ignore'))
bball_100poss2 = bball_100poss2.loc[bball_100poss2['MP'] > 250]
bball_100poss2.fillna(0, inplace=True)
bball_100poss2 = bball_100poss2.set_index(bball_100poss2['Player'])
bball_100poss2 = bball_100poss2.drop(['Player','Pos','Age','Tm','G','GS','MP',
                                      'ORtg','DRtg'],axis = 1)
bball_100poss2016 = bball_100poss2.loc[bball_100poss2['Year'] == 2016]
bball_100poss2016.head()
#kmeans(bball_100poss2)
# Out:
#                 FG   FGA    FG%   3P  3PA    3P%   2P   2PA    2P%   FT  ...   \
# Player                                                                   ...
# Quincy Acy     6.5  11.7  0.556  1.0  2.7  0.388  5.5   9.0  0.606  2.7  ...
# Steven Adams   6.4  10.5  0.613  0.0  0.0  0.000  6.4  10.5  0.613  2.8  ...
# Arron Afflalo  7.7  17.3  0.443  2.0  5.2  0.382  5.7  12.2  0.469  2.4  ...
# Alexis Ajinca  8.6  18.1  0.476  0.0  0.1  0.000  8.6  18.1  0.478  3.0  ...
# Cole Aldrich   8.4  14.1  0.596  0.0  0.0  0.000  8.4  14.1  0.596  3.8  ...
#
#                ORB   DRB   TRB  AST  STL  BLK  TOV   PF   PTS  Year
# Player
# Quincy Acy     3.6   6.7  10.3  1.5  1.6  1.3  1.5  5.6  16.8  2016
# Steven Adams   5.4   7.7  13.1  1.5  1.0  2.2  2.1  5.5  15.7  2016
# Arron Afflalo  0.5   5.3   5.8  3.1  0.5  0.2  1.8  3.1  19.7  2016
# Alexis Ajinca  4.3  11.2  15.5  1.8  1.1  2.1  3.1  7.7  20.3  2016
# Cole Aldrich   5.4  12.7  18.0  3.1  2.9  4.3  4.0  8.7  20.5  2016
#
# [5 rows x 22 columns]

# %%
df = bball_100poss2016
from scipy.spatial.distance import pdist, squareform

dist = pdist(df, 'euclidean')
df_dist = pd.DataFrame(squareform(dist))
DistMatrix = df_dist.as_matrix()
test = DistMatrix[0] < 8
test = df.iloc[list(test)]
print(test)
import networkx as nx
#G = nx.from_numpy_matrix(DistMatrix)
#nx.draw_networkx(G)
#plt.show()
# Out:
#                       FG   FGA    FG%   3P  3PA    3P%   2P   2PA    2P%   FT  \
# Player
# Quincy Acy           6.5  11.7  0.556  1.0  2.7  0.388  5.5   9.0  0.606  2.7
# Steven Adams         6.4  10.5  0.613  0.0  0.0  0.000  6.4  10.5  0.613  2.8
# Lavoy Allen          5.9  11.5  0.516  0.0  0.0  0.000  5.9  11.5  0.516  1.4
# Tony Allen           6.8  14.9  0.458  0.5  1.3  0.357  6.4  13.6  0.468  2.9
# Al-Farouq Aminu      6.4  15.4  0.416  2.7  7.5  0.361  3.7   7.9  0.468  2.5
# Chris Andersen       4.9   9.2  0.528  0.5  1.8  0.286  4.4   7.4  0.586  3.2
# Justin Anderson      5.6  13.8  0.406  1.7  6.5  0.265  3.9   7.2  0.533  3.5
# Kyle Anderson        5.7  12.1  0.468  0.5  1.5  0.324  5.2  10.6  0.488  2.5
# Darrell Arthur       7.3  16.2  0.452  1.5  3.9  0.385  5.8  12.3  0.473  1.3
# Adreian Payne        ...   2.1   9.4  11.5  3.0  1.7  1.1  3.7  8.0  13.7
# Otto Porter          ...   2.1   6.3   8.4  2.6  2.2  0.7  1.5  3.5  18.7
# Glenn Robinson       ...   1.2   5.5   6.6  2.5  1.7  0.9  1.8  2.1  16.7
# Robert Sacre         ...   5.0   6.3  11.3  2.2  0.6  1.6  1.9  6.7  13.7
# JaKarr Sampson       ...   2.0   6.1   8.1  2.0  1.0  1.4  3.0  6.1  15.9
# Mike Scott           ...   2.3   6.6   8.9  3.4  1.1  0.7  1.8  4.4  20.0
# Thabo Sefolosha      ...   1.5   7.9   9.4  3.0  2.4  1.0  1.9  3.1  13.5
# Tiago Splitter       ...   3.8   6.4  10.2  2.6  1.7  1.0  2.0  6.1  17.2
# Jason Thompson       ...   3.4  10.9  14.3  3.1  1.3  2.1  1.6  8.6  15.7
# P.J. Tucker          ...   3.2   6.7   9.8  3.4  2.0  0.4  2.1  3.9  12.5
# Noah Vonleh          ...   3.9   9.1  13.0  1.3  1.2  1.1  2.1  6.5  12.1
# Justise Winslow      ...   1.9   7.4   9.3  2.7  1.6  0.6  2.2  4.2  11.5
# Jeff Withey          ...   4.5   9.4  13.9  1.6  1.7  4.2  2.2  6.0  17.4
# Metta World Peace    ...   1.6   6.0   7.6  2.3  1.9  0.9  1.3  5.7  15.0
# Cody Zeller          ...   3.9   9.0  12.9  2.0  1.6  1.8  1.9  5.8  18.0
#
#                      Year
# Player
# Quincy Acy           2016
# Steven Adams         2016
# Lavoy Allen          2016
# Tony Allen           2016
# Al-Farouq Aminu      2016
# Chris Andersen       2016
# Justin Anderson      2016
# Kyle Anderson        2016
# Darrell Arthur       2016
# Harrison Barnes      2016
# Brandon Bass         2016
# Nemanja Bjelica      2016
# Trevor Booker        2016
# Chase Budinger       2016
# Willie Cauley-Stein  2016
# Bryce Dejean-Jones   2016
# Luol Deng            2016
# Boris Diaw           2016
# Gorgui Dieng         2016
# Jared Dudley         2016
# Jeremy Evans         2016
# Langston Galloway    2016
# Taj Gibson           2016
# Aaron Gordon         2016
# Jerami Grant         2016
# Maurice Harkless     2016
# Montrezl Harrell     2016
# Spencer Hawes        2016
# Roy Hibbert          2016
# Solomon Hill         2016
# ...                   ...
# Jonas Jerebko        2016
# Amir Johnson         2016
# James Johnson        2016
# Tyler Johnson        2016
# Frank Kaminsky       2016
# Ryan Kelly           2016
# Trey Lyles           2016
# Ian Mahinmi          2016
# Chris McCullough     2016
# Josh McRoberts       2016
# Timofey Mozgov       2016
# Mike Muscala         2016
# Larry Nance Jr.      2016
# Johnny O'Bryant      2016
# Kelly Oubre          2016
# Adreian Payne        2016
# Otto Porter          2016
# Glenn Robinson       2016
# Robert Sacre         2016
# JaKarr Sampson       2016
# Mike Scott           2016
# Thabo Sefolosha      2016
# Tiago Splitter       2016
# Jason Thompson       2016
# P.J. Tucker          2016
# Noah Vonleh          2016
# Justise Winslow      2016
# Jeff Withey          2016
# Metta World Peace    2016
# Cody Zeller          2016
#
# [63 rows x 22 columns]

# %%
from scipy.cluster.hierarchy import dendrogram, linkage
from scipy.spatial.distance import squareform

dists = squareform(dist)
linkage_matrix = linkage(dists, "single")
dendrogram(linkage_matrix)
plt.title("test")
plt.show()
